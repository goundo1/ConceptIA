# %% [markdown]
# # EDA — Home Credit Default Risk (application_train.csv)
# **Objectifs**
# - Réaliser une EDA complète sur `application_train.csv`.
# - Formuler et tester au moins 3 hypothèses statistiques (avec `scipy.stats`).
# - Documenter chaque étape, intuitions et questionnements (cellules Markdown).

# %% [markdown]
# 1. Imports et réglages

# %%
# Imports & réglages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_ind, chi2_contingency, mannwhitneyu

plt.rcParams.update({'figure.figsize': (10,6)})
sns.set(style='whitegrid')
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Imports & réglages
#       2 import os
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'
